# %% [markdown]
# ## Performing Full Outer Join and Cross Join on Spark Data Frames

# %% [markdown]
# 1. Union of left and right outer join
# 2. join using `'user_id'`
# 3. join using `u.user_id == ce.user_id`
# 4. help(crossjoin)
# 5. u.crossjoin(ce).show()

# %%
# %run './01 Setup Data Sets to perform joins.ipynb'
# Out:
# 24/03/26 23:27:45 WARN Utils: Your hostname, Qasim resolves to a loopback address: 127.0.1.1; using 172.30.54.131 instead (on interface eth0)
# 24/03/26 23:27:45 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/26 23:27:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/03/26 23:27:47 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/03/26 23:27:47 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 24/03/26 23:27:47 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# +---------+-----------------------------+-------------------+---------+-------------------+
# ...
