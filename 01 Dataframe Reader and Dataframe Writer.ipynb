# %%
print('hello world')

# %% [markdown]
# # Reading Data
#
# ## Schema Inference
#
# 1. Read CSV (spark.read.format) -> creates a job while inferring schema
# 2. Print Schema (.schema, .printSchema)
# 3. Display(df) - Action
#     a. Data Visualization
#     b. Data Profile (Feature Engineering, Data Analysis)

# %% [markdown]
# ## Explicit Schema Definition
#
# 1. StructType, StructField, StringType
# 2. Read CSV with expilict schema - Transformation, not an action -> no Job created

# %% [markdown]
# ## DDL Schema
#
# 1. SQL Style Schema
# 2. Read CSV with expilict schema - Transformation, not an action -> no Job created

# %% [markdown]
# # Writing Data
#
# ## Write Parquet content to the File System
# 2. display(dbutils.fs.ls(file path))

# %% [markdown]
# ## Write to a table
#
# 1. .saveAsTable() - reference in the metastore
# 2. .writeTo().createOrReplace()
# 3. Read data from the table
