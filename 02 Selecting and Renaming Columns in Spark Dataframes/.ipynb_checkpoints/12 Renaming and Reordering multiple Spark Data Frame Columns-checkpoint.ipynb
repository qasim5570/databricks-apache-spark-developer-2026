# %% [markdown]
# ##  Renaming and Reordering multiple Spark Data Frame Columns

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Renaming and Reordering multiple Spark Data Frame Columns").getOrCreate()

import datetime
users_list = [
    {
        'id': 1,
        'first_name': 'John',
        'last_name': 'Doe',
        'email': 'john.doe@example.com',
        'phone_numer' : {'UAE_Mobile': '+971 54 7400113', 'PAK_Mobile': '+92 300 5638080'},
        'is_customer': True,
        'amount_paid': 123.45,
        'customer_from': datetime.date(2023, 1, 15),  # Date in YYYY-MM-DD format
        'last_updated_ts': datetime.datetime(2024, 1, 21, 20, 5, 46)  # Timestamp in YYYY-MM-DD HH:MM:SS format
    },
    {
        'id': 2,
        'first_name': 'Jane',
        'last_name': 'Smith',
        'email': 'jane.smith@example.com',
        'phone_numer' : {'UAE_Mobile': '+971 99 7666666', 'PAK_Mobile': '+92 300 0000000'},
        'is_customer': True,
        'amount_paid': 0.0,
        'customer_from': datetime.date(2022, 11, 10),
        'last_updated_ts': datetime.datetime(2024, 1, 21, 20, 5, 46)
    },
    {
        'id': 3,
        'first_name': 'Jack',
        'last_name': 'Alpha',
        'email': 'jack.alpha@example.com',
        'phone_numer' : {'UAE_Mobile': '+971 99 7666555'},
        'is_customer': False,
        'amount_paid': 0.0,
        'customer_from': datetime.date(2022, 11, 10),
        'last_updated_ts': datetime.datetime(2024, 1, 21, 20, 5, 46)
    }
    # Add more user dictionaries as needed
]
# Out:
# 24/03/03 13:39:34 WARN Utils: Your hostname, Qasim resolves to a loopback address: 127.0.1.1; using 172.30.54.131 instead (on interface eth0)
# 24/03/03 13:39:34 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/03 13:39:35 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/03/03 13:39:36 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/03/03 13:39:36 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 24/03/03 13:39:36 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 24/03/03 13:39:36 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 24/03/03 13:39:36 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.

# %%
from pyspark import Row

users_df = spark.createDataFrame([Row(**users) for users in users_list])
users_df
# Out:
# DataFrame[id: bigint, first_name: string, last_name: string, email: string, phone_numer: map<string,string>, is_customer: boolean, amount_paid: double, customer_from: date, last_updated_ts: timestamp]

# %%
help(users_df.toDF)
# Out:
# Help on method toDF in module pyspark.sql.dataframe:
#
# toDF(*cols: str) -> 'DataFrame' method of pyspark.sql.dataframe.DataFrame instance
#     Returns a new :class:`DataFrame` that with new specified column names
#
#     .. versionadded:: 1.6.0
#
#     .. versionchanged:: 3.4.0
#         Supports Spark Connect.
#
#     Parameters
#     ----------
#     *cols : tuple
#         a tuple of string new column name. The length of the
#         list needs to be the same as the number of columns in the initial
#         :class:`DataFrame`
#
#     Returns
#     -------
#     :class:`DataFrame`
#         DataFrame with new column names.
#
#     Examples
#     --------
#     >>> df = spark.createDataFrame([(14, "Tom"), (23, "Alice"),
#     ...     (16, "Bob")], ["age", "name"])
#     >>> df.toDF('f1', 'f2').show()
#     +---+-----+
#     | f1|   f2|
#     +---+-----+
#     | 14|  Tom|
#     | 23|Alice|
#     | 16|  Bob|
#     +---+-----+

# %%
target_names = ['id', 'first_name', 'last_name']

required_names = ['user_id', 'first_name', 'user_last_name']

# %%
users_df. \
    select(target_names). \
    show()
# Out:
# +---+----------+---------+
# | id|first_name|last_name|
# +---+----------+---------+
# |  1|      John|      Doe|
# |  2|      Jane|    Smith|
# |  3|      Jack|    Alpha|
# +---+----------+---------+

# %%
users_df. \
    select(target_names). \
    toDF(required_names). \
    show()
# Out:
# ---------------------------------------------------------------------------
# PySparkTypeError                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 users_df. \
#       2     select(target_names). \
#       3     toDF(required_names). \
#       4     show()
#
# File ~/airflow_venv_20231230/lib/python3.8/site-packages/pyspark/sql/dataframe.py:5482, in DataFrame.toDF(self, *cols)
#    5480 for col in cols:
#    5481     if not isinstance(col, str):
# -> 5482         raise PySparkTypeError(
#    5483             error_class="NOT_LIST_OF_STR",
#    5484             message_parameters={"arg_name": "cols", "arg_type": type(col).__name__},
#    5485         )
#    5486 jdf = self._jdf.toDF(self._jseq(cols))
#    5487 return DataFrame(jdf, self.sparkSession)
#
# PySparkTypeError: [NOT_LIST_OF_STR] Argument `cols` should be a list[str], got list.

# %%
users_df. \
    select(target_names). \
    toDF(*required_names). \
    show()
# Out:
# +-------+----------+--------------+
# |user_id|first_name|user_last_name|
# +-------+----------+--------------+
# |      1|      John|           Doe|
# |      2|      Jane|         Smith|
# |      3|      Jack|         Alpha|
# +-------+----------+--------------+
