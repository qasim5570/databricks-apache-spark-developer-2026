# %% [markdown]
# ## Specifying Schema using Spark Types

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Specifying Schema using Spark Types").getOrCreate()
# Out:
# 24/02/18 11:12:12 WARN Utils: Your hostname, Qasim resolves to a loopback address: 127.0.1.1; using 172.30.54.131 instead (on interface eth0)
# 24/02/18 11:12:12 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/02/18 11:12:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/02/18 11:12:14 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/02/18 11:12:14 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 24/02/18 11:12:14 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 24/02/18 11:12:14 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 24/02/18 11:12:14 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.

# %%
import datetime

users_list = [
    [1, 'John', 'Doe', 'john.doe@example.com', True, 123.45, datetime.date(2023, 1, 15), datetime.datetime(2024, 1, 21, 20, 5, 46)],
    [2, 'Jane', 'Smith', 'jane.smith@example.com', True, 0.0, datetime.date(2022, 11, 10), datetime.datetime(2024, 1, 21, 20, 5, 46)],
    [3, 'Jack', 'Alpha', 'jack.alpha@example.com', False, None, None, datetime.datetime(2024, 1, 21, 20, 5, 46)],
]

# %%
from pyspark.sql.types import *

# %%
users_schema = StructType([
    StructField('id', IntegerType()),
    StructField('first_name', StringType()),
    StructField('last_name', StringType()),
    StructField('email', StringType()),
    StructField('is_customer', BooleanType()),
    StructField('amount_paid', FloatType()),
    StructField('customer_from', DateType()),
    StructField('last_updated_ts', TimestampType())
    
])

# %%
type(users_schema)
# Out:
# pyspark.sql.types.StructType

# %%
df_users = spark.createDataFrame(users_list, schema=users_schema)

# %%
df_users
# Out:
# DataFrame[id: int, first_name: string, last_name: string, email: string, is_customer: boolean, amount_paid: float, customer_from: date, last_updated_ts: timestamp]

# %%
type(df_users)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_users.show()
# Out:
# +---+----------+---------+--------------------+-----------+-----------+-------------+-------------------+
# | id|first_name|last_name|               email|is_customer|amount_paid|customer_from|    last_updated_ts|
# +---+----------+---------+--------------------+-----------+-----------+-------------+-------------------+
# |  1|      John|      Doe|john.doe@example.com|       true|     123.45|   2023-01-15|2024-01-21 20:05:46|
# |  2|      Jane|    Smith|jane.smith@exampl...|       true|        0.0|   2022-11-10|2024-01-21 20:05:46|
# |  3|      Jack|    Alpha|jack.alpha@exampl...|      false|       NULL|         NULL|2024-01-21 20:05:46|
# +---+----------+---------+--------------------+-----------+-----------+-------------+-------------------+
