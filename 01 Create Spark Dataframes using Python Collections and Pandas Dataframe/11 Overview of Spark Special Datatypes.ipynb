# %% [markdown]
# ## Overview of Spark Special Datatypes

# %% [markdown]
# ### Special Types supported by Spark
# -  Array
# -  Struct
# -  Map

# %% [markdown]
# #### List and Dicts can be implicitly converted into Spark Array and Map

# %% [markdown]
# #### We need to use few Spark APIs to convert Python data structures into STRUCT type
