# %% [markdown]
# ## Overview of Writing Data Files into Spark Data Frames

# %% [markdown]
# 1. Writing files `json`, `csv`, `parquet`
# 2. `format` and `save`
# 3. Specifying `option` as arguments or using `option` or `options`
# 4. Writing compressed files
# 5. `spark.write.option(inferSchema=True).toDF(*cols)`
# 7. `help(spark.write.csv/json/parquet)`
# 8. `spark.write.csv(path, sep, schema, header)` and `spark.read.format('csv').load(path_to_csv, sep, comma, header)` can have same options
# 9. `spark.write.csv(path, sep, schema, header)`
# 10. `spark.write.options(sep, schema).csv(path)`
# 11. `spark.write.format('csv').save(path_to_write)`
# 12. `df.inputFiles`
# 13. if `df.write.format('csv', sep='|').save(path)`, then normal read wihtout `df.read.format('csv')` without mentioning would return one column only. Make sure to do `df.read.format('csv', sep='|')` to read it correctly
# 14. `df.write.mode('overwrite).csv('path_to_write')` and `df.write.csv('path_to_write', mode='overwrite')` are both correct
# 15. `df.write.option('key', 'value').csv`
# 16. Compression using all the file formats
# 18. If file is not comma separated, it returns `NULLS`. - *Check*

# %% [markdown]
# ## Parquet
#
# 1. spark.conf.get(`spark.sql.parquet.compression.codec, none/gzip/snappy`) value will be default compression
