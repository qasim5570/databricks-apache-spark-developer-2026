# %% [markdown]
# ## Operators Boolean OR on same column of Spark Data Frame and IN Operator

# %% [markdown]
# 1. Get a list of users whose City is NULL or empty string using both the syntaxes
# 2. isNull()
# 3. Or |
# 4. filter()
# 5. Get a list of users whose City is either Houston or Dallas using both the syntaxes
# 6. isin(): non-sql syntax
# 7. IN(): sql syntax
# 8. Get a list of users whose City is either Houston or Dallas or NULL using both the syntaxes
# 9. IN() cannot be used for NULL, use BOOLEAN OR operator
# 10. Check the condition with isNull()
# 11. greater than or less than
# 12. <= or >=
# 13. isnan()
# 14. use filter before and after select e.g., select all users who are male and are cusotmers as well
# 15.
