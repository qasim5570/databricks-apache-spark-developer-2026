# %% [markdown]
# ## Date and Time Manipulation Functions using Spark Data Frames

# %% [markdown]
# 1. current_date
# 2. current_timestamp
# 3. create dummy dataframe
# 4. to_date
# 5. to_timestamp
# 6. use these functions with lit
# 7. check collect()
