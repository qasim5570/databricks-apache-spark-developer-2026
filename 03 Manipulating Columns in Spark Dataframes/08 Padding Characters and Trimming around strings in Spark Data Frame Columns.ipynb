# %% [markdown]
# ## Padding and Trimming Characters around strings in Spark Data Frame Columns

# %% [markdown]
# 1. lpad, rpad
# 3. create dummy dataframe
# 4. lpad, literal
# 5. help(lpad)
# 6. select, alias
# 7. `Task:` create employee dataframe
# 8. ltrim, rtrim
# 9. sparkSQL engine with expr or selectExpr
# 10.

# %%
spark.sql('DESCRIBE FUNCTION ltrim').show(truncate=False)
