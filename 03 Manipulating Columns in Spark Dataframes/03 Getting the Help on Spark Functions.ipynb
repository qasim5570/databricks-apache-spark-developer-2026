# %% [markdown]
# ## Getting the Help on Spark Functions

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Getting the Help on Spark Functions").getOrCreate()
# Out:
# 24/03/13 22:08:22 WARN Utils: Your hostname, Qasim resolves to a loopback address: 127.0.1.1; using 172.30.54.131 instead (on interface eth0)
# 24/03/13 22:08:22 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/13 22:08:23 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
