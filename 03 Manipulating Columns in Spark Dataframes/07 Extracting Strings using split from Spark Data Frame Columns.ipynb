# %% [markdown]
# ## Extracting Strings using split from Spark Data Frame Columns

# %% [markdown]
# 1. Create dummy list
# 2. Create dataframe
# 3. split, help(split)
# 4. limit
# 5. explode
# 6. split(lit(), '')
# 7. select element by index
# 8. `Task`: create employees df with 2 phone numbers, use the above mentioned functions
# 9. use select and withColumn together
# 10. get area code(1-3), country code(3), phone number prefix(3), and phone number(4)
# 11. get phone count
